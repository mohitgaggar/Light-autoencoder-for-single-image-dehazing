# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd
# Out:
# /root

# %%
cd /content/drive/My Drive/dataset/H/videos/frames1
# Out:
# /content/drive/My Drive/dataset/H/videos/frames1

# %%
from keras.datasets import mnist
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Conv2D,AveragePooling2D,MaxPooling2D,Flatten,UpSampling2D,Conv2DTranspose,Input,BatchNormalization
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
# Out:
# Using TensorFlow backend.

# %%
autoencoder=tf.keras.models.load_model("8325model.model")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0705 06:20:17.081725 140672366708608 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0705 06:20:17.083267 140672366708608 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %%
#image=cv2.imread("image.jpg")
#converted_img = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
pickle_in = open("V5.pickle","rb")
V5 = pickle.load(pickle_in)

# %%
print(V5[0])
# Out:
# [[[0.88235294 0.90980392 0.88235294]
#   [0.88235294 0.90980392 0.88235294]
#   [0.88235294 0.90980392 0.88235294]
#   ...
#   [0.81568627 0.83921569 0.82352941]
#   [0.81568627 0.83921569 0.82352941]
#   [0.81568627 0.83921569 0.82352941]]
#
#  [[0.88235294 0.90980392 0.88235294]
#   [0.88235294 0.90980392 0.88235294]
#   [0.88235294 0.90980392 0.88235294]
#   ...
#   [0.81568627 0.83921569 0.82352941]
#   [0.81568627 0.83921569 0.82352941]
#   [0.81568627 0.83921569 0.82352941]]
#
#  [[0.88235294 0.90980392 0.88235294]
#   [0.88235294 0.90980392 0.88235294]
#   [0.88235294 0.90980392 0.88235294]
#   ...
#   [0.81568627 0.83921569 0.82352941]
#   [0.81568627 0.83921569 0.82352941]
#   [0.81568627 0.83921569 0.82352941]]
#
#  ...
#
#  [[0.21960784 0.21960784 0.17254902]
#   [0.21568627 0.21568627 0.16862745]
#   [0.20784314 0.20784314 0.16078431]
#   ...
#   [0.25882353 0.28235294 0.10980392]
#   [0.25882353 0.28235294 0.10980392]
#   [0.25882353 0.28235294 0.10980392]]
#
# ...

# %%
pre=autoencoder.predict(V5)

# %%
# !pip install scipy

# %%
cv2.imwrite("imagetest.jpg",pre[0])

# %%
#from scipy.misc import imfilter, imread
from skimage import color, data, restoration
from scipy.signal import convolve2d as conv2
import scipy.misc as lol

# %%
image = lol.imread("imagetest.jpg")
psf = np.ones((5, 5)) / 25
image = conv2(rand_array[0], psf, 'same')
image += 0.1 * image.std() * np.random.standard_normal(image.shape)
deconvolved = restoration.wiener(image, psf, 1, clip=False)
plt.imshow(deconvolved, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-0fb683bc9679> in <module>()
# ----> 1 image = lol.imread("imagetest.jpg")
#       2 psf = np.ones((5, 5)) / 25
#       3 image = conv2(rand_array[0], psf, 'same')
#       4 image += 0.1 * image.std() * np.random.standard_normal(image.shape)
#       5 deconvolved = restoration.wiener(image, psf, 1, clip=False)
#
# AttributeError: module 'scipy.misc' has no attribute 'imread'

# %%
print(pre[0])
# Out:
# [[[0.70251226 0.70922923 0.6939552 ]
#   [0.764978   0.77202904 0.72973764]
#   [0.74578863 0.75302935 0.7308879 ]
#   ...
#   [0.7372935  0.7580641  0.7416792 ]
#   [0.7055265  0.7252302  0.7001587 ]
#   [0.57006884 0.5928878  0.595089  ]]
#
#  [[0.79963744 0.79298556 0.7774002 ]
#   [0.8076972  0.7980163  0.76712954]
#   [0.7748013  0.78116304 0.76015943]
#   ...
#   [0.71158504 0.724841   0.7217077 ]
#   [0.6676418  0.6803612  0.6769766 ]
#   [0.5829117  0.61249316 0.63059795]]
#
#  [[0.8105655  0.8124248  0.8121573 ]
#   [0.8273891  0.8253536  0.8158357 ]
#   [0.7967081  0.79883856 0.8005678 ]
#   ...
#   [0.7215817  0.7287991  0.7203109 ]
#   [0.68758905 0.70154214 0.69998085]
#   [0.60179406 0.6280202  0.6352266 ]]
#
#  ...
#
#  [[0.11444867 0.14312804 0.10813004]
#   [0.07892707 0.10977867 0.06037751]
#   [0.10494152 0.13681263 0.09348017]
#   ...
#   [0.20259988 0.22088881 0.11780813]
#   [0.14923754 0.17816481 0.08045313]
#   [0.14669177 0.16869646 0.10399008]]
#
# ...

# %%
rand_array = np.uint8(255*pre)
#plt.imshow(rand_array[1])
plt.imshow(pre[10])
plt.show()
plt.imshow(V5[0])
plt.show()
# Out:
# W0705 06:22:02.699449 140672366708608 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
   count=0
from PIL import Image


for img in range(rand_array.shape[0]):
  image=cv2.fastNlMeansDenoisingColored(rand_array[img],None,10,10,7,21)
  im = Image.fromarray(image)
  im.save("/content/drive/My Drive/H/videos/test/out_frames/frame%d.jpg" % count)
  count+=1

# %%
image_folder = "/content/drive/My Drive/H/videos/test/out_frames"
video_name = 'vid.mp4'

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 30, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()

# %%
a=[]
#converted_img = cv2.cvtColor(rand_array[0], cv2.COLOR_RGB2BGR)
a.append(cv2.fastNlMeansDenoisingColored(rand_array[0],None,10,10,7,21)) 
#a[0] = cv2.cvtColor(a[0], cv2.COLOR_BGR2RGB) 
plt.imshow(a[0])
plt.show()
plt.imshow(rand_array[0])
plt.show()
plt.imshow(V[0])
plt.show()
